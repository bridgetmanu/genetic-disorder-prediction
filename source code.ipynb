# %% [markdown]
# <a href="https://colab.research.google.com/github/bridgetmanu/genetic-disorder-prediction/blob/main/source%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read file and familiarize with the content

# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
import sqlite3

data1 = pd.read_csv("/home/observations.csv")
data2 = pd.read_csv("/home/species_info.csv")

# clean data
# remove NA values
data1 = data1.dropna()
data2 = data2.dropna()

# view dataframe
pd.DataFrame(data1)
pd.DataFrame(data2)


sql = sqlite3.connect("species_info.db")
data2.to_sql("species_info", sql, if_exists = "replace")
con = sql.cursor()

# about 10 of the species in the dataframe are threatened
obs1 = pd.read_sql_query("SELECT * FROM species_info where conservation_status = 'Threatened'", sql)
pd.DataFrame(obs1)
# about 16 of the species in the dataframe are Endangered
obs2 = pd.read_sql_query("SELECT * FROM species_info where conservation_status = 'Endangered'", sql)
pd.DataFrame(obs2)
# Out:
#     index        category               scientific_name  \
# 0       8          Mammal                   Canis lupus
# 1       9          Mammal                   Canis rufus
# 2      34          Mammal             Myotis grisescens
# 3      39          Mammal                Myotis sodalis
# 4      72          Mammal  Glaucomys sabrinus coloratus
# 5     173            Bird                Grus americana
# 6     276            Bird           Vermivora bachmanii
# 7     343            Bird             Picoides borealis
# 8     540            Fish          Etheostoma percnurum
# 9     570            Fish               Noturus baileyi
# 10   2497  Vascular Plant                 Geum radiatum
# 11   3275            Fish             Chasmistes liorus
# 12   4446          Mammal       Ovis canadensis sierrae
# 13   4448          Mammal                   Canis lupus
# 14   4505            Bird       Gymnogyps californianus
# 15   4601       Amphibian                  Rana sierrae
#
# ...
